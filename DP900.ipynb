# %% [markdown]
# 1. Descriptive analytics tells you
#     - ~~what is most likely to occur in the future~~
#     - <span style = "color: red">what occurred in the past</span>
#
# 2. Normalization involves eliminating relationships between database tables - No
# Normalizing a database reduces data redundancy - Yes
# Normalization improves data integrity - Yes
#
# 3. An extract, transform, and load (ETL) process requires
#     - ~~a matching schema in the data source and the data target~~
#     - <span style = "color: red">data that is fully processed before being loaded to the target data store</span>
#     - Extract, transform, and load (ETL) is a data pipeline used to collect data from various sources, transform the data according to business rules, and load it into a destination data store.
#
# 4. In batching process,
#     - latency in delivering data processing results is acceptable
#     - When to use batch processing, You might expect latencies when using batch processing. For many situations, however, this type of delay before the transfer of data begins is not a big issue - the processes that use this function are not mission critical at the exact moment.
#
# 5. Transcribing audio files is an example of
#     - ~~prescriptive analytics~~
#     - <span style = "color: red">cognitive analytics </span>
#
# 6. Match the the types of analytics that can be used to answer the business questions.
# - Why did sales increase last month? A: Diagnostic
# - How do I allocate my budget to buy different inventory items? A: ~~Predictive~~ <span style = "color: red">Prescriptive </span>
#
# - Which people are mentioned in a company's business documents? A: ~~Prescriptive~~ <span style = "color: red">Cognitive</span>
#
# - What's happening: Descriptive, Why's happening: Diagnostic, What will happen: Predictive, What actions should we take: Prescriptive
#
# 7. Json object shown
# - Customer is a root object
# - Address is a nested object
# - Social media is a nested array
#
# 8. Data model shown
# - The data model is a star schema
# - Customer is a dimension table
#  - In computing, the star schema is the simplest style of data mart schema and is the approach most widely used to develop data warehouses and dimensional data marts. The star schema consists of one or more fact tables referencing any number of dimension tables. The star schema is an important special case of the snowflake schema, and is more effective for handling simpler queries.
#
# 9. The massively parallel processing (MPP) engine of Azure Synapse Analytics
# - distributes processing across control nodes
# -<span style = "color: red">distributes processing across compute nodes </span>
#
# 10. An object associated with a table thtat sorts and stores the data rows in the table based on their key values
# - a clustered index
#
# 11. A relational database is appropriate for scenarios that involve a high volume of
#     - transactional writes
#
#
# 12.
#     - Batch processing can output data to a file store - No <span style = "color: red">Yes </span>
#     - Batch processing can output data to a relational database - Yes
#     - Batch processing can output data to a NoSQL database - Yes
#     - Big data solutions often use long-running batch jobs to filter, aggregate, and otherwise prepare the data for analysis. Usually these jobs involve reading source files from scalable storage (like HDFS, Azure Data Lake Store, and Azure Storage), processing them, and writing the output to new files in scalable storage.
#
# 13.
#     - The CRM system: Extract
#     - The data warehouse: Load
#     - An in-memory data integration tool: Transform
#
# 14. A visualization that shows a university's current student enrollment versus the maximum capacity is an exmaple of
#     - descriptive analytics
#
# 15.
#     - A chart of colored, nested rectangles that displays individual data points represented by the size and color of a relative rectangle: Tree map
#     - A chart that displays the major contributors of a selected result or value: Key influencer
#     - A chart that shows the relationship between two numerical values: Scatter
#
#
# 16. Data in the account must replicate outside the Azure region automatically. Which two types of replication can you use for the storage account?
# - ~~locally-redundant storage~~ <span style = "color: red">read-access geo-redundant storage </span>
# - geo-redundant storage
#
#     - Azure Storage offers two options for copying your data to a secondary region:
#         - Geo-redundant storage (GRS)
#         - Geo-zone-redundant storage (GZRS)
#
# 17.
# - Platform as a service (Paas) database offerings in Azure require less setup and configuration that infrastructure as a service (Iaas) - <span style = "color: red">yes</span>
# - Paas provide end users with the ability to control and update the operating system version - <span style = "color: red">no, you manage the applications and services you develop, and the cloud service provider typically manages everything else.</span>
# - All relation and non-relational platform as a service offerings ca be paused to reduce cost - <span style = "color: red">no, There really is no way to pause / stop billing for your Azure SQL Database.</span>
#
# 18. Which statement is an example of Data Manipulation Language (DML)?
#     - Insert
#     - insert: DML (Data Manipulation Language), GRANT, DENY, REVOKE: DCL (Data Control Language)
#
# 19. You have a SQL query that combines customer data and order data. The query includes calculated columns.
# You need to create a database object that would allow other users to rerun the same SQL query.
# What should you create?
# - View
#
# 20. A key/value data store is optimized for
# - ~~table joins~~
# - <span style = "color: red">simple look-ups, table joins depend on the keys but this is more for searching thorugh index </span>
#
# 21. Match the types of data to the appropriate Azure data services.
#  - Image files: Azure Blob storage
#  - ~~Image files~~<span style = "color: red"> Relationships between employees</span>: Azure Cosmos DB Gremlin API
#  - Key/value pairs, ~~Relationships between employees~~: Azure Table Storage
#  - Relationships = Gremlin (nodes, edges), Image = Blob, Table = Key/values
#
# 22. Match the Azure Data Lake Storage Gen2 terms to the appropriate levels in the hierarchy.
#     - Azure Resource Group
#         - Azure Storage account
#             - <span style = "color: red">~~Container~~</span>
#                 - File Share
#                     - Folders
#                         - Files
#
# 23.  What are two characteristics of real-time data processing? Each correct answer presents a complete solution.
#     - low latency is expected
#     - Datat is processed as it is created
#
# 24. Match the Azure Data Factory components to the appropriate descriptions.
#     - A representation of data structures within data stores: dataset
#     - The information used to connect to external resources: linked service
#     - a logical grouping of activities that performs a unit of work and can be scheduled: Pipeline
#
# 25. Match the types of workloads to the appropriate scenarios.
#     - data for a product catalog is loaded every 12 hours: batch
#     - thousands of data sets per second in real time: streaming
#     - updates every 1 million transactions: batch

# %% [markdown]
# 26. Question 13
#
# 27. predictive analysis for 4th quarter
#
# 28. data manipulation language (DML): Update
#
# 29. Creatubg closed caption text for audio files is an example of cognitive analytics
#
# 30. A visualization that illustrates a university's current student enrollment per department is an example of descriptive analytics
#
# 31. An extract, load, and transform (ELT) process requires a target data store powerful enough to transform data
#
# 32.  You need to create an Azure resource to store data in Azure Table storage. az storage account create
# - if the account is already created, then use <span style = "color: red">az storage container create</span>
#
# 33. The Azure Cosmos DB Core API enables the use of SELECT statements to retrieve documents from Azure Cosmos DB
#
# 34. You need to modify a view in a relational database by adding a new column. use ~~UPDATE~~ <span style = "color: red">Alter</span>
#     - to add a column in a view Alter
#
# 35.
#     - extract, transform, and load (ETL) can reduce the transfer of sensitive data to destinations systems. - YES
#     - Extract, load, and transform (ELT) transforms data by using a compute resource independent of the source system and destination system - No
#     - Extract, load, and transform (ELT) minimizes the time it takes to copy large volumes of data to destination systems - ~~No~~ <span style = "color: red">YES</span>
#
# 36. You plan to deploy a PostgreSQL database to Azure.
# Which hosting model corresponds to the available deployment options? To answer, select the appropriate options in the answer area.
#     - PostgreSQL on Azure VMs: ~~Platform as a service~~ <span style = "color: red">Infrastructure as a service</span>
#         - PostgreSQL on Azure VMs option falls into the industry category of IaaS.
#     - Azure Database for PostgreSQL: ~~Infrastructure as a service~~ <span style = "color: red">Platform as a service</span>
#
# 37. ~~Key-value~~  <span style = "color: red">Graph databases </span>stores natively supports the analysis of **relationships between entities.**
#
# 38.  Which Azure storage solution provides native support for POSIX-compliant access control lists (ACLs)?
#     - ~~Azure Files~~ <span style = "color: red">Azure Data Lake Storage Gen 2</span>
#
# 39. Relational data is stored in a tabular form of rows and columns
#
# 40. A clustered index physically sorts the data in a table based on the values in a specified column
#
# 41. A block of code that runs in a database is called a stored procedure
#
# 42.
#     - Why did the sales increase last month? - Diagnostic
#     - Provide specific guidance on how to allocate current budget - Prescriptive
#     - Detec images of the company's logo included in pdf documents - Cognitive
#
# 43. A view presents content defined by a query
#
# 44. Which type of database is Azure Database for PostgreSQL? - Platform as a service
#
# 45. Which storage solution supports access control lists (ACLs) at the file and folder level? - Azure Data Lake Storage
#
# 46. A Treemap is a chart of colored rectangles. The size of the rectangles represent the relative value of each item.
#
# 47. What is a characteristic of batch processing
#     - C. There is a noticeable time delay between ingesting data and obtaining the data processing results
#
# <span style = "color: red">48</span>. In a SQL statement, Max and Min are examples of aggregate functions
#
# 49.
# - A job that processes sales data once daily is an example of batch workload - yes
# - A job that calculates a rolling average temperature reading is an example of a streaming workload - yes
# - A job that calculates average revenue per product for the last month is an example of a streaming workload - no
#
# 50. In a relational database, each row in a table has the same set of columns

# %% [markdown]
# 51.
#     - Normalizing a database increases the throughput of writing transactions - Yes (writing is optimized for normalized databases)
#     - Analytics systems are more normalized than transactional systems - No
#     - Normalizing a database results in queries that require more joins - yes
#
# 52. Graph databases natively supports analysis of relationships between entitites
#
# 53. A key/value data store is optimized for simple lookups
#
# 54. In an infrastructure as a service instance of microsoft sql server on azure you manage the ~~postgresql server~~ <span style = "color: red"> virtual machine </span> that hosts sql server
#     - In Iaas, you need to manage the VMs and OS
#
# 55. Varying fields for each entity in a JSON document is an example of ~~unstructured data~~ <span style = "color: red"> semi-structured data </span>
#
# 56. A JSON document is an example of semi-structured data
#
# 57.  Which property of a transactional workload guarantees that each transaction is treated as a single unit that either succeeds completely or fails completely? - ~~isolation~~ <span style = "color: red"> atomicity </span>
#     - A.C.I.D. properties: Atomicity, Consistency, Isolation, and Durability
# Atomicity - each statement in a transaction (to read, write, update or delete data) is treated as a single unit. Either the entire statement is executed, or none of it is executed. This property prevents data loss and corruption from occurring if, for example, if your streaming data source fails mid-stream.
#
# 58. employee and department graph network database -> graph data store
#
# 59.  Which type of database contains nodes and edges? - Graph
#
# 60. ~~A data analyst~~ <span style = "color: red">A data engineer</span> is reponsible for identifying which business rules must be applied to the data of a company.
#     - a little iffy meh
#
# 61. Relational data uses keys to enforce relationships between different tables
#
# 62. use UPDATE to change the existing data from the databse
#
# 63. Your company needs to implement a relational database in Azure. The solution must minimize ongoing maintenance. Which Azure service should you use? - Azure SQL Database
#     - Minimize maintenance: so it should a PaaS + Relational Database = Azure SQL Database
#
# 64. You are writing a set of SQL queries that administrators will use to troubleshoot an Azure SQL database. You need to embed documents and query results into a SQL notebook. <span style = "color: red">Azure Data Studio</span>
#
# 65.
# - Table: A database object that holds data
# - View: A database object whose content is defined by a query
# - Index: A database object that helps improve the speed of data retrieval
#
# 66.  You have an e-commerce application that reads and writes data to an Azure SQL database. - Online Transaction Processing (OLTP)
#     - Online Transaction Processing is a type of data processing that consists of executing a number of transactions occurring concurrently
#
# 67. When can you use an Azure Resource Manager template? - ~~to control which services and feature administrator and developrs can deploy from the Azure portal~~
#     - to automate the creation of an interdependent group of Azure resources in a repeatable way
#     - You can automate deployments and use the practice of infrastructure as code. In code, you define the infrastructure that needs to be deployed..To implement infrastructure as code for your Azure solutions, use Azure Resource Manager templates (ARM templates). The template is a JavaScript Object Notation (JSON) file that defines the infrastructure and configuration for your project.
#
#
# 68. You have an Azure SQL database that you access directly from the Internet. You recently changed the public IP address of your computer.
# After changing the IP address, you can no longer access the database. You can connect to other resources in Azure. What is a possible cause of the issue? - ~~Dynamic Host Configuration Protocol~~ <span style = "color: red">a database-level firewall</span>
#
# 69.
# - Microsoft SQL Server Management Studio
# - Azure Data Studio
# - Microsoft SQL Server Data Tools
#
# 70.
# - Relational database tables contains columns and rows: yes
# - Indexes in a relational database describe the data types in a table: no
# - A database view is a virtual table whose content is defined by a query: yes
#
# 71. which command line tool can you use to query Azure SQL database?
#     - ~~azdata~~ <span style = "color: red">sqlcmd</span>
#     - https://learn.microsoft.com/en-us/sql/tools/sqlcmd/sqlcmd-utility?view=sql-server-ver16&viewFallbackFrom=sql-server-ver1
#
# 72.
#     - Azure SQL Database includes a managed backup service -  <span style = "color: red">yes</span>
#     - Azure SQL Database has built-in high availability -  <span style = "color: red">no</span>
#     - Azure SQL Database can use Azure Defender -  <span style = "color: red">yes</span>
#
# 73.
#     - You can use Azure Data Studio to query a Microsoft SQL Server big data cluster: <span style = "color: red">yes</span>, https://docs.microsoft.com/en-us/sql/azure-data-studio/what-is?view=sql-server-ver15
#     - You can use Microsfot SQL Server Management Studio to query an Azure Synapse Analytics data warehouse: <span style = "color: red">yes</span>,  https://docs.microsoft.com/en-us/learn/modules/query-azure-sql-data-warehouse/4-query-dw-using-ssms
#     - You can use MySQL workbench to query Azure Dtabase for MariaDB databases: <span style = "color: red">yes</span>, https://docs.microsoft.com/en-us/azure/mariadb/connect-workbench
#
# 74.
# - Paas database offerings in Azure provide built-in high availability: <span style = "color: red">yes</span>
# - PaaS database offerings in Azure provide configurable scaling options: ~~no~~ <span style = "color: red">yes</span>
# - PaaS database offerings in Azure reduce the administrative overhead for managing hardware: <span style = "color: red">yes</span>
# - https://docs.microsoft.com/en-us/azure/azure-sql/database/sql-database-paas-overview
#
#
# 75. INSERT INTO dbo.Products (ProducID, ProductName, Price, ProductDescription) VALUES (1, 'Clamp', 12.48, 'Workbench clamp')
#     - dbo.Products: table
#     - ProductName: column

# %% [markdown]
# 76.
# - you must apply operating system updates to Azure SQL databases regularly: ~~yes~~ <span style = "color: red">no</span>
# - You need a Microsoft 365 subscription ot create an Azure SQL databse: no
# - You can use existing Microsoft SQL server licences to reduce the cost of Azure SQL databases: yes
#
# 77. Which statement is an example of Data definition language?
#     - Create
#
# 78.
# - Azure Data Stduio can be used to query an Azure SQL database from a device that runs macOC: yes
# - Microsoft SQL server management studio enables users to create and use SQL notebooks: no
# - Azure Data Studio can be used to restore a database: ~~no~~ <span style = "color: red">yes</span>, they can take backups and restores
#
# 79. You are deploying a software as a service (SaaS) application that requires a relational database for Online Transaction Processing (OLTP).
# Which Azure service should you use to support the application?
#     - ~~Azure Synapse Analytics~~ <span style = "color: red">Azure SQL Database</span>
#
# 80. What are two benefits of platform as a service (PaaS) relational database offerings in Azure, such as Azure SQL Database? Each correct answer presents a complete solution.
#     - ~~complete control over backup and restore processes~~ <span style = "color: red">Access to the latest features</span>
#     - reduced administrative effort for managing the server infrastructure
#     - PaaS manages backups and regular updates
#
# 81.
# - If you have PaaS database in Azure, you are responsible for applying operating system updates: no
# - If you have PaaS database in Azure, backups are performed automatically: yes
# - If you have PaaS database in Azure, you are responsible for installation of the database engine: no
#
# 82. SQL problem: SELECT // GROUP BY
#
# 83. When you create an Azure SQL database, which account can always connect to the database?
#     - ~~the Azure Active Directory (Azure AD) administrator account~~ <span style = "color: red">the server admin login account of the logical server</span>, admin login and an associated password which refers to the server admin
#
# 84. Which statement is an example of Data Definition Language (DDL)?
#     - DROP
#
# 85. A team of developers has computers that run Windows 10 and Ubuntu Desktop. The developers need to connect to and query an Azure SQL database from each of their computers. The developers require code assistance features such as IntelliSense. What should the developers use?
#     - Azure Data Studio
#
# 86. Transparent Data Encryption (TDE) encrypts the <span style = "color: red">database to protect data at rest</span>
#
# 87. You need to ensure that users use multi-factor authentication (MFA) when connecting to an Azure SQL database. Which type of authentication should you use?
#     - ~~certificate authentication~~ <span style = "color: red">Azure Active Directory</span>, certification authentication does not support MFA
#
# 88.  What is a benefit of hosting a database on Azure SQL managed instance as compared to an Azure SQL database?
#     - <span style = "color: red">native support for cross-database queries and transactions</span>, https://docs.microsoft.com/en-us/azure/azure-sql/database/features-comparison
#
# 89. By default, each Azure SQL database is protected by ~~Azure Firewall~~<span style = "color: red">server-level firewall</span>, Azure Firewall is a managed, cloud-based network security service that **protects your Azure Virtual Network resources**. It's a fully stateful firewall as a service with built-in high availability and unrestricted cloud scalability.
#
# 90. You need to design and model a database by using a graphical tool that supports project-oriented offline database development. What should you use? : <span style = "color: red">Microsoft SQL Server Data Tools</span>
#
# 91.
# - Firewall: Prevent access to an Azure SQL database from another network
# - Authentication: Support Azure Active Directory (Azure AD) sign-ins to an Azure SQL database
# - Encryption: Ensure that sensitive data never appears as plain text in an Azure SQL database
#
# 92. You have a transactional application that stores data in an Azure SQL managed instance. When should you implement a read-only database replica?
#     <span style = "color: red">- You need to generate reports without affecting the transactional workload</span>
#
# 93. A relational database must be used when ~~a dynamic schema is required~~<span style = "color: red">strong consistency guarantees are required</span>, relational database are static schemas
#
# 94. Relational data uses keys to enforce relationships betweend different tables
#
# 95. A view is a virtual table that contains content defined by a query
#
# 96. You need to query a table named Products in an Azure SQL database.Which three requirements must be met to query the table from the internet? Each correct answer presents part of the solution.
#     - ~~You must be assigned the Reader role for the resource group that contains the database~~Resource group permissions is not required to query an Azure SQL database table.
#     - You must have SELECT access to the Products table
#     - <span style = "color: red">You must have a user in the database</span>
#     - <span style = "color: red">Your IP address must be allowed to connect to the database </span>
#
# 97. Which clause should you use in a SELECT statement to combine rows in one table with rows in another table? JOIN
#
# 98. Your company needs to ensure that an Azure virtual machine can connect to Azure SQL database without exposing the databases to the internet.
#     - <span style = "color: red">Azure Private Link</span>, Azure Private Link enables you to access Azure PaaS Services (for example, Azure Storage and SQL Database) and Azure hosted customer-owned/partner services over a private endpoint in your virtual network.
#
# 99.
# - Azure SQL Database single database: a serverless configuration
# - ~~Azure SQL Database elastic pool~~ <span style = "color: red">Azure SQL Managed instance</span>: A database that has the highest compatibility with on-premises Microsoft SQL server
# - ~~Azure SQL Managed instance~~ <span style = "color: red">Azure SQL Database elastic pool</span>: a low-cost, low-maintenance database
#
# 100. Which T-SQL statement should be used to instruct a databvasemanagemetn systemt to use an index instead of performing a full table scan?
#     - WHERE <span style = "color: red">SELECT</span>, SELECT is a statement and WHERE is a clause.

# %% [markdown]
# 101. Azure Synapse Analytics is a platform as a service relational data service that uses massively parallel processing (MPP)
#     - Azure Synapse Analytics is an platform as a service (PAAS) that combines data integration, warehousing, and analytics into one solution. Azure Synapse Analytics offers cloud-based, relational data warehousing services, massively parallel processing (MPP) scale-out technology, and enough computational power to efficiently manage petabytes and petabytes of data.
#
# 102. A clustered index physically sorts the data in a table based on the values in a specified column
#
# 103. Question 75
#
# 104. In a relational database, the primary key uniquely identifies each row in a table
#
# 105. A view presents content defined by a query
#
# 106. Which Azure service provides the highest compatibility for databases migrated from Microsoft SQL server 2019 enterprise edition?
#     - <span style = "color: red">Azure SQL managed instance</span>
# 107. Which setting can only be configured during the creation of an Azure Cosmos DB account?
#     - <span style = "color: red">API</span>,
#
# 108.
# - Key/value: A list of application user names and for each the default language
# - Object: A collection of medical images and their associated metadata
# - Graph: Employee data that shows the relationships between employees
#
# 109. You have an Azure Cosmos DB account that uses the Core API. Which two settings can you configure at the container level?
#     - <span style = "color: red">Throughput</span>
#     - <span style = "color: red">the partition key</span>
#
# 110. ~~Key/value for data that stores semi-structured~~ <span style = "color: red">Type of data store: columnar (document based)</span>
#     - https://docs.microsoft.com/en-us/azure/architecture/guide/technology-choices/data-store-overview#column-family-databases
#
# 111.  Which storage solution supports role-based access control (RBAC) at the file and folder level?
#     - <span style = "color: red">Azure Data Lake Storage</span>
#     - Azure Data Lake Storage Gen2 implements an access control model that supports both Azure role-based access control (Azure RBAC) and POSIX-like access control lists (ACLs). This article summarizes the basics of the access control model for Data Lake Storage Gen2.
#
# 112. You need to store data in Azure Blob storage for seven years to meet your company's compliance requirements. The retrieval time of the data is unimportant. The solution must minimize storage costs. Which storage tier should you use?
#     - Archive
#     - Retrieval Rate: Hot - Frequent, Cold - every 30 days, Archive - every 180 days
#
# 113.  Which type of non-relational data store supports a flexible schema, stores data as JSON files, and stores the all the data for an entity in the same document?
#     - document
#
# 114.
# - Gremlin API: Graph data
# - MongoDB API: JSON document
# - ~~Cassandra API~~<span style = "color: red">Table API</span>: Key/value data
# - Gremlin API - This API allows users to make graph queries and stores data as edges and vertices
# MongoDB API - This API stores data in a document structure, via BSON format
# Cassandra API - This API stores data in column-oriented schema.
# Table API - This API stores data in key/value format
#
# 115. To configure an Azure Storage account to support both security at the folder level and atomic directory manipulation, <span style = "color: red">enable hierarchical namespace</span>
#     - This allows the collection of objects/files within an account to be organized into a hierarchy of directories and nested subdirectories in the same way that the file system on your computer is organized.
#
# 116. You can query a graph database in Azure Cosmos DB as ~~nodes and edges by using the Gremlin language~~ <span style = "color: red">as a JSON document by using a SQL-like language</span>
#
# 117.  When provisioning an Azure Cosmos DB account, which feature provides redundancy within an Azure region?
#     - <span style = "color: red">availability zone</span>
#     - Enabling redundancy across availability zones makes Azure Cosmos DB resilient to zone outages at the cost of increased charges.
#
# 118.  What is a benefit of the Azure Cosmos DB Table API as compared to Azure Table storage?
#     - <span style = "color: red">multi-master model</span>
#
# 119. Your company needs to design a database that shows how changes in network traffic in one area of a network affect network traffic in other areas of the network. Which type of data store should you use?
#     - graph
#
# 120.
# - Azure Databricks can consume data from Azure SQL Database: yes
# - Azure Databricks can consume data from Azure Event Hubs: yes
# - Azure Databricks can consume data from Azure Cosmos DB: yes
#
# 121.
# - Azure Cosmos DB: Enables the use of SQL queries against data stored in JSON documents
#     - In Azure Cosmos DB's SQL (Core) API, items are stored as JSON. The type system and expressions are restricted to deal only with JSON types.
# - ~~Azure Blob storage~~ <span style = "color: red">Azure Files</span>: Enables users to access data by using the Server Message Block version 3 protocol
#     - Azure Files offers native cloud file sharing services based on the SMB protocol.
#
# 122. When provisioning an Azure Cosmos DB **account**, you need to specify which type of API you will use
#
# 123. You need to store data by using Azure Table storage. What should you create first?
#     - A storage account
#     - First create an Azure storage account, then use Table service in the Azure portal to create a table.
#
# 124. You need to recommend a data store service that meets the following requirement: native SQL API access, configurable indexes
#     - <span style = "color: red">Azure Cosmos DB</span>
#     - Azure Cosmos DB comes with native Core (SQL) API support.
# 125.
# - Azure Table storage within a single Azure Storage account supports multiple concurrent ~~**reads / writes**~~ <span style = "color: red">read but not write</span> in different Azure regions
#     - Geo-redundant storage (with GRS or GZRS) replicates your data to another physical location in the secondary region to protect against regional outages. However, that data is available to be read only if the customer or Microsoft initiates a failover from the primary to secondary region
# - An Azure Cosmos DB account that uses the Table API supports multiple concurrent <span style = "color: red">**reads / writes**</span> in different Azure regions
#     - Azure Cosmos DB supports multi-region writes.
