# %% [markdown]
# 1. Descriptive analytics tells you
#     - ~~what is most likely to occur in the future~~
#     - <span style = "color: red">what occurred in the past</span>
#
# 2. Normalization involves eliminating relationships between database tables - No
# Normalizing a database reduces data redundancy - Yes
# Normalization improves data integrity - Yes
#
# 3. An extract, transform, and load (ETL) process requires
#     - ~~a matching schema in the data source and the data target~~
#     - <span style = "color: red">data that is fully processed before being loaded to the target data store</span>
#     - Extract, transform, and load (ETL) is a data pipeline used to collect data from various sources, transform the data according to business rules, and load it into a destination data store.
#
# 4. In batching process,
#     - latency in delivering data processing results is acceptable
#     - When to use batch processing, You might expect latencies when using batch processing. For many situations, however, this type of delay before the transfer of data begins is not a big issue - the processes that use this function are not mission critical at the exact moment.
#
# 5. Transcribing audio files is an example of
#     - ~~prescriptive analytics~~
#     - <span style = "color: red">cognitive analytics </span>
#
# 6. Match the the types of analytics that can be used to answer the business questions.
# - Why did sales increase last month? A: Diagnostic
# - How do I allocate my budget to buy different inventory items? A: ~~Predictive~~ <span style = "color: red">Prescriptive </span>
#
# - Which people are mentioned in a company's business documents? A: ~~Prescriptive~~ <span style = "color: red">Cognitive</span>
#
# - What's happening: Descriptive, Why's happening: Diagnostic, What will happen: Predictive, What actions should we take: Prescriptive
#
# 7. Json object shown
# - Customer is a root object
# - Address is a nested object
# - Social media is a nested array
#
# 8. Data model shown
# - The data model is a star schema
# - Customer is a dimension table
#  - In computing, the star schema is the simplest style of data mart schema and is the approach most widely used to develop data warehouses and dimensional data marts. The star schema consists of one or more fact tables referencing any number of dimension tables. The star schema is an important special case of the snowflake schema, and is more effective for handling simpler queries.
#
# 9. The massively parallel processing (MPP) engine of Azure Synapse Analytics
# - distributes profcessing across control nodes
# -<span style = "color: red">distributes processing across compute nodes </span>
#
# 10. An object associated with a table thtat sorts and stores the data rows in the table based on their key values
# - a clustered index
#
# 11. A relational database is appropriate for scenarios that involve a high volume of
#     - transactional writes
#
# 12.
#     - Batch processing can output data to a file store - No <span style = "color: red">Yes </span>
#     - Batch processing can output data to a relational database - Yes
#     - Batch processing can output data to a NoSQL database - Yes
#     - Big data solutions often use long-running batch jobs to filter, aggregate, and otherwise prepare the data for analysis. Usually these jobs involve reading source files from scalable storage (like HDFS, Azure Data Lake Store, and Azure Storage), processing them, and writing the output to new files in scalable storage.
#
# 13.
#     - The CRM system: Extract
#     - The data warehouse: Load
#     - An in-memory data integration tool: Transform
#
# 14. A visualization that shows a university's current student enrollment versus the maximum capacity is an exmaple of
#     - descriptive analytics
#
# 15.
#     - A chart of colored, nested rectangles that displays individual data points represented by the size and color of a relative rectangle: Tree map
#     - A chart that displays the major contributors of a selected result or value: Key influencer
#     - A chart that shows the relationship between two numerical values: Scatter
#
#
# 16. Data in the account must replicate outside the Azure region automatically. Which two types of replication can you use for the storage account?
# - ~~locally-redundant storage~~ <span style = "color: red">read-access geo-redundant storage </span>
# - geo-redundant storage
#
#     - Azure Storage offers two options for copying your data to a secondary region:
#         - Geo-redundant storage (GRS)
#         - Geo-zone-redundant storage (GZRS)
#
# 17.
# - Platform as a service (Paas) database offerings in Azure require less setup and configuration that infrastructure as a service (Iaas) - <span style = "color: red">yes</span>
# - Paas provide end users with the ability to control and update the operating system version - <span style = "color: red">no, you manage the applications and services you develop, and the cloud service provider typically manages everything else.</span>
# - All relation and non-relational platform as a service offerings ca be paused to reduce cost - <span style = "color: red">no, There really is no way to pause / stop billing for your Azure SQL Database.</span>
#
# 18. Which statement is an example of Data Manipulation Language (DML)?
#     - Insert
#     - insert: DML (Data Manipulation Language), GRANT, DENY, REVOKE: DCL (Data Control Language)
#
# 19. You have a SQL query that combines customer data and order data. The query includes calculated columns.
# You need to create a database object that would allow other users to rerun the same SQL query.
# What should you create?
# - View
#
# 20. A key/value data store is optimized for
# - ~~table joins~~
# - <span style = "color: red">simple look-ups, table joins depend on the keys but this is more for searching thorugh index </span>
#
# 21. Match the types of data to the appropriate Azure data services.
#  - Image files: Azure Blob storage
#  - ~~Image files~~<span style = "color: red"> Relationships between employees</span>: Azure Cosmos DB Gremlin API
#  - Key/value pairs, ~~Relationships between employees~~: Azure Table Storage
#  - Relationships = Gremlin (nodes, edges), Image = Blob, Table = Key/values
#
# 22. Match the Azure Data Lake Storage Gen2 terms to the appropriate levels in the hierarchy.
#     - Azure Resource Group
#         - Azure Storage account
#             - <span style = "color: red">~~Container~~</span>
#                 - File Share
#                     - Folders
#                         - Files
#
# 23.  What are two characteristics of real-time data processing? Each correct answer presents a complete solution.
#     - low latency is expected
#     - Datat is processed as it is created
#
# 24. Match the Azure Data Factory components to the appropriate descriptions.
#     - A representation of data structures within data stores: dataset
#     - The information used to connect to external resources: linked service
#     - a logical grouping of activities that performs a unit of work and can be scheduled: Pipeline
#
# 25. Match the types of workloads to the appropriate scenarios.
#     - data for a product catalog is loaded every 12 hours: batch
#     - thousands of data sets per second in real time: streaming
#     - updates every 1 million transactions: batch

# %% [markdown]
# 26. Question 13
#
# 27. predictive analysis for 4th quarter
#
# 28. data manipulation language (DML): Update
#
# 29. Creatubg closed caption text for audio files is an example of cognitive analytics
#
# 30. A visualization that illustrates a university's current student enrollment per department is an example of descriptive analytics
#
# 31. An extract, load, and transform (ELT) process requires a target data store powerful enough to transform data
#
# 32.  You need to create an Azure resource to store data in Azure Table storage. az storage account create
# - if the account is already created, then use <span style = "color: red">az storage container create</span>
#
# 33. The Azure Cosmos DB Core API enables the use of SELECT statements to retrieve documents from Azure Cosmos DB
#
# 34. You need to modify a view in a relational database by adding a new column. use ~~UPDATE~~ <span style = "color: red">Alter</span>
#     - to add a column in a view Alter
#
# 35.
#     - extract, transform, and load (ETL) can reduce the transfer of sensitive data to destinations systems. - YES
#     - Extract, load, and transform (ELT) transforms data by using a compute resource independent of the source system and destination system - No
#     - Extract, load, and transform (ELT) minimizes the time it takes to copy large volumes of data to destination systems - ~~No~~ <span style = "color: red">YES</span>
#
# 36. You plan to deploy a PostgreSQL database to Azure.
# Which hosting model corresponds to the available deployment options? To answer, select the appropriate options in the answer area.
#     - PostgreSQL on Azure VMs: ~~Platform as a service~~ <span style = "color: red">Infrastructure as a service</span>
#         - PostgreSQL on Azure VMs option falls into the industry category of IaaS.
#     - Azure Database for PostgreSQL: ~~Infrastructure as a service~~ <span style = "color: red">Platform as a service</span>
#
# 37. ~~Key-value~~  <span style = "color: red">Graph databases </span>stores natively supports the analysis of **relationships between entities.**
#
# 38.  Which Azure storage solution provides native support for POSIX-compliant access control lists (ACLs)?
#     - ~~Azure Files~~ <span style = "color: red">Azure Data Lake Storage Gen 2</span>
#
# 39. Relational data is stored in a tabular form of rows and columns
#
# 40. A clustered index physically sorts the data in a table based on the values in a specified column
#
# 41. A block of code that runs in a database is called a stored procedure
#
# 42.
#     - Why did the sales increase last month? - Diagnostic
#     - Provide specific guidance on how to allocate current budget - Prescriptive
#     - Detec images of the company's logo included in pdf documents - Cognitive
#
# 43. A view presents content defined by a query
#
# 44. Which type of database is Azure Database for PostgreSQL? - Platform as a service
#
# 45. Which storage solution supports access control lists (ACLs) at the file and folder level? - Azure Data Lake Storage
